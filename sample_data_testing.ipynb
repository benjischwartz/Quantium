# %%
# packages for data manipulation

import numpy as np
import pandas as pd

# packages for visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in sales data
sales = pd.read_csv('sales_data_sample.csv', encoding='ISO-8859-1')

# %%
with open('sales_data_sample.csv') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='sales_data_sample.csv' mode='r' encoding='UTF-8'>

# %%
sales.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
# Total sales by month
sales.groupby('MONTH_ID').SALES.sum()
# Out:
# MONTH_ID
# 1      785874.44
# 2      810441.90
# 3      754501.39
# 4      669390.96
# 5      923972.56
# 6      454756.78
# 7      514875.97
# 8      659310.57
# 9      584724.27
# 10    1121215.22
# 11    2118885.67
# 12     634679.12
# Name: SALES, dtype: float64

# %%
# Total sales by country
sales.groupby('COUNTRY').QUANTITYORDERED.sum()
# Out:
# COUNTRY
# Australia       6246
# Austria         1974
# Belgium         1074
# Canada          2293
# Denmark         2197
# Finland         3192
# France         11090
# Germany         2148
# Ireland          490
# Italy           3773
# Japan           1842
# Norway          2842
# Philippines      961
# Singapore       2760
# Spain          12429
# Sweden          2006
# Switzerland     1078
# UK              5013
# USA            35659
# Name: QUANTITYORDERED, dtype: int64

# %%
# Total sales by year
sales.groupby('YEAR_ID').SALES.sum()
# Out:
# YEAR_ID
# 2003    3516979.54
# 2004    4724162.60
# 2005    1791486.71
# Name: SALES, dtype: float64

# %%
# Create a new column with clients' full names
sales['NAME'] = sales['CONTACTFIRSTNAME'] + sales['CONTACTLASTNAME']

# %%
sales.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# 1          Reims   NaN      51100  France      EMEA         Henriot
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
#
#   CONTACTFIRSTNAME DEALSIZE            NAME
# 0             Kwai    Small          KwaiYu
# 1             Paul    Small     PaulHenriot
# 2           Daniel   Medium  DanielDa Cunha
# 3            Julie   Medium      JulieYoung
# 4            Julie   Medium      JulieBrown
#
# [5 rows x 26 columns]

# %%
# Groupby client name (NAME), count the number of previous orders
previous_orders = sales.groupby('NAME', as_index=False)['ORDERNUMBER'].count()

# %%
# rename the columns
previous_orders.columns = ['NAME', 'Number_orders']

# %%
previous_orders.head()
# Out:
#              NAME  Number_orders
# 0    AdrianHuxley             46
# 1  AkikoShimamura             32
# 2     AllenNelson             24
# 3        AnnBrown             26
# 4      AnnaO'Hara             46

# %%
# add this new dataframe to the sales dataframe using a left-merge (keeps all rows of sales DF)
dfinal = sales.merge(previous_orders, on="NAME", how='left')

# %%
# rename columns
dfinal.columns = ['ORDERNUMBER' if x=='ORDERNUMBER_x' else x for x in dfinal.columns]
dfinal.columns = ['Total_Customer_Orders' if x=='ORDERNUMBER_y' else x for x in dfinal.columns]
dfinal.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...           CITY  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...            NYC
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          Reims
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          Paris
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...       Pasadena
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...  San Francisco
#
#    STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 0     NY      10022     USA       NaN              Yu             Kwai
# 1    NaN      51100  France      EMEA         Henriot             Paul
# 2    NaN      75508  France      EMEA        Da Cunha           Daniel
# 3     CA      90003     USA       NaN           Young            Julie
# 4     CA        NaN     USA       NaN           Brown            Julie
#
#   DEALSIZE            NAME Total_Customer_Orders
# 0    Small          KwaiYu                    49
# 1    Small     PaulHenriot                    41
# 2   Medium  DanielDa Cunha                    20
# 3   Medium      JulieYoung                    30
# 4   Medium      JulieBrown                    41
#
# [5 rows x 27 columns]

# %%
# Earliest order
dfinal.ORDERDATE.min()
# Out:
# '1/10/2003 0:00'

# %%
# Testing extracting rows with a specific month and year
test_slice = dfinal[(dfinal['MONTH_ID'] == 1) & (dfinal['YEAR_ID'] == 2003)]

# %%
test_slice.head()
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 26         10103               26      100.0               11  5404.62
# 133        10103               42      100.0                4  5398.26
# 212        10103               27      100.0                8  3394.98
# 266        10104               34      100.0                1  5958.50
# 367        10104               41      100.0                9  4615.78
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...     CITY  STATE  \
# 26   1/29/2003 0:00  Shipped       1         1     2003  ...  Stavern    NaN
# 133  1/29/2003 0:00  Shipped       1         1     2003  ...  Stavern    NaN
# 212  1/29/2003 0:00  Shipped       1         1     2003  ...  Stavern    NaN
# 266  1/31/2003 0:00  Shipped       1         1     2003  ...   Madrid    NaN
# 367  1/31/2003 0:00  Shipped       1         1     2003  ...   Madrid    NaN
#
#     POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  \
# 26        4110  Norway      EMEA      Bergulfsen            Jonas   Medium
# 133       4110  Norway      EMEA      Bergulfsen            Jonas   Medium
# 212       4110  Norway      EMEA      Bergulfsen            Jonas   Medium
# 266      28034   Spain      EMEA          Freyre            Diego   Medium
# 367      28034   Spain      EMEA          Freyre            Diego   Medium
#
#                 NAME Total_Customer_Orders
# 26   JonasBergulfsen                    32
# 133  JonasBergulfsen                    32
# 212  JonasBergulfsen                    32
# 266      DiegoFreyre                   259
# 367      DiegoFreyre                   259
#
# [5 rows x 27 columns]

# %%
test_slice.SALES.sum()
# Out:
# 129753.6

# %%
# Feature: Total sales last month vs prev month
# function returns percentage of last month compared to the previous month
def total_sales_lastvsprev_month(month, year):
    
    # Handle out of bounds (earliest date is 10th Jan 2003)
    if month == 1 and year == 2003 : return 100
    
    # Find total orders for last month
    last = dfinal[(dfinal['MONTH_ID'] == month) & (dfinal['YEAR_ID'] == year)].SALES.sum()
        
    # Handle January condition (go back to Dec of previous year)
    if month == 1 : 
        month = 12
        year = year - 1    
    else:
        month = month - 1
        
    prev = dfinal[(dfinal['MONTH_ID'] == month) & (dfinal['YEAR_ID'] == year)].SALES.sum()
        
    return (last/prev) * 100;

# %%
# Test function
total_sales_lastvsprev_month(1, 2003)
total_sales_lastvsprev_month(2, 2003)
total_sales_lastvsprev_month(3, 2003)
# Out:
# 123.90629141558006

# %%
# Print sales by month for 2003
num_bins = 12
x = list(range(1, 12))
n, bins, patches = plt.hist(total_sales_lastvsprev_month(x, 2003), num_bins, facecolor='blue', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3r/z3hrm8hn1_500h31w81bh6bh0000gn/T/ipykernel_51943/403750958.py in <module>
#       2 num_bins = 12
#       3 x = list(range(2, 12))
# ----> 4 n, bins, patches = plt.hist(total_sales_lastvsprev_month(x, 2003), num_bins, facecolor='blue', alpha=0.5)
#
# /var/folders/3r/z3hrm8hn1_500h31w81bh6bh0000gn/T/ipykernel_51943/3301863935.py in total_sales_lastvsprev_month(month, year)
#       7
#       8     # Find total orders for last month
# ----> 9     last = dfinal[(dfinal['MONTH_ID'] == month) & (dfinal['YEAR_ID'] == year)].SALES.sum()
#      10
#      11     # Handle January condition (go back to Dec of previous year)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# /usr/local/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     259         #  The ambiguous case is object-dtype.  See GH#27803
#     260         if len(lvalues) != len(rvalues):
# --> 261             raise ValueError(
#     262                 "Lengths must match to compare", lvalues.shape, rvalues.shape
#     263             )
#
# ValueError: ('Lengths must match to compare', (2823,), (10,))
