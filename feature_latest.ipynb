# %%
# import pandas for data manipulation
import pandas as pd
import numpy as np
from itertools import product

# %%
# Read in new dataset
sales = pd.read_csv('customer_data_latest.csv', encoding='utf-8')
sales = sales[sales.filter(regex='^(?!Unnamed)').columns]

# Remove unecessary 'SESSION_TYPE' and 'PROPOSITION_TYPE' columns
sales = sales.drop(columns=['SESSION_TYPE', 'PROPOSITION_TYPE'])

# Sort by 'DATE'
sales["DATE"] = pd.to_datetime(sales["DATE"])
sales = sales.sort_values(by="DATE")
sales.head(10)
# Out:
#           DATE PROPOSITION    SESSION  SITE  SALES  CUST_ID  ACTIVE_SUB
# 342 2017-01-02    In-store      Night     9     89       76           1
# 890 2017-01-04    Delivery      Night     2    282      104           0
# 861 2017-01-05     Pick-up  Afternoon     2    182      127           1
# 496 2017-01-07    In-store  Afternoon     5    302       78           1
# 871 2017-01-07    Delivery      Night     2    297      103           0
# 788 2017-01-08     Pick-up    Morning     7    209      110           0
# 573 2017-01-11    Delivery    Morning     6     87      154           0
# 822 2017-01-11    In-store    Morning     4    136      102           1
# 718 2017-01-11     Pick-up    Morning     8    471       97           1
# 622 2017-01-12    In-store    Morning     7    265      162           1

# %%
# Pad out missing dates
def pad_missing_dates(df):
        
    # Get the start and end date of dataframe
    start_date = pd.to_datetime(df['DATE'].min())
    end_date = pd.to_datetime(df['DATE'].max())    
    dates = pd.date_range(start=start_date, end=end_date)
    
    # Get all unique combinations
    props = sales.PROPOSITION.unique()
    sessions = sales.SESSION.unique()
    sites = sales.SITE.unique()
    
    # Create skeleton dataframe with entire date range   
    skeleton = pd.DataFrame(list(product(dates, props, sessions, sites)), 
                                 columns=['DATE', 'PROPOSITION', 'SESSION', 'SITE'])
    skeleton.sort_values(['DATE', 'SITE', 'PROPOSITION', 'SESSION'])

    # Perform outer merge
    df = pd.merge(df, skeleton, how='outer', on=['DATE', 'PROPOSITION', 'SESSION', 'SITE'])
    df2 = df.sort_values(by=['DATE', 'PROPOSITION', 'SESSION', 'SITE']).reset_index(drop='True')
    
    # Fill in zeroes, change proposition, session to string types
    df2 = df2.fillna(0)
    return df2

# %%
padded = pad_missing_dates(sales)
padded.head()
# Out:
#         DATE PROPOSITION    SESSION  SITE  SALES  CUST_ID  ACTIVE_SUB
# 0 2017-01-02    Delivery  Afternoon     1    0.0      0.0         0.0
# 1 2017-01-02    Delivery  Afternoon     2    0.0      0.0         0.0
# 2 2017-01-02    Delivery  Afternoon     3    0.0      0.0         0.0
# 3 2017-01-02    Delivery  Afternoon     4    0.0      0.0         0.0
# 4 2017-01-02    Delivery  Afternoon     5    0.0      0.0         0.0

# %%
# Default columns (and relevant functions) to aggregate on
DEFAULT_AGGREGATIONS = {'SALES': 'sum', 'CUST_ID': 'sum', 'ACTIVE_SUB': 'sum', 
                        'SALES_DELTA': 'sum', 'SUB_DELTA': 'sum'}

def group_on_variable(cols, df):
    """
    Helper method for grouping on and removing columns from
    the sales dataframe. We bake in the particular necessary aggregations 
    for our columns.
    """
    
    # Change CUST_ID to be '1' if customer, '0' if not
    df['CUST_ID'] = df['CUST_ID'].astype(bool)
    
    aggregation_functions = {
        col: f for (col, f) in DEFAULT_AGGREGATIONS.items() if col in df
    }

    df2 = df.groupby(cols, as_index=False).aggregate(aggregation_functions)
    
    # Rename CUST_ID to TOTAL_CUST and ACTIVE_SUB to TOTAL_ACTIVE
    df2.rename(columns={'CUST_ID': 'TOTAL_CUST', 'ACTIVE_SUB': 'TOTAL_ACTIVE'}, inplace=True)
    df2.sort_values(['DATE'])
    return df2

# %%
group_on_variable(['DATE'], padded).head(10)
# Out:
#         DATE  SALES  TOTAL_CUST  TOTAL_ACTIVE
# 0 2017-01-02   89.0           1           1.0
# 1 2017-01-03    0.0           0           0.0
# 2 2017-01-04  282.0           1           0.0
# 3 2017-01-05  182.0           1           1.0
# 4 2017-01-06    0.0           0           0.0
# 5 2017-01-07  599.0           2           1.0
# 6 2017-01-08  209.0           1           0.0
# 7 2017-01-09    0.0           0           0.0
# 8 2017-01-10    0.0           0           0.0
# 9 2017-01-11  694.0           3           2.0

# %%
def rolling_week(df, num_weeks, granularity):
    
    gap = num_weeks * 7
    
    # Do rolling sum
    current = df.shift(-gap).rolling(gap)['SALES'].sum()
    previous = df.rolling(gap)['SALES'].sum()
    df['DATA'] = (current/previous - 1) * 100
    df['DATA'] = df['DATA'].replace({np.inf:np.NaN})
    
    # Shift data down
    df['WEEK_TREND'] = df.groupby(granularity)['DATA'].shift(gap)
    return df

# %%
def week_trend(sales, num_weeks, granularity):
    new_sales = group_on_variable(granularity, sales)
    granularity.remove('DATE')
    return new_sales.groupby(granularity, as_index=False).apply(rolling_week, num_weeks, granularity).drop(columns='DATA')

# %%
pd.set_option('display.max_rows', 1500)
result = week_trend(padded, 1, ['DATE', 'SITE'])
result.tail(30)
# Out:
#             DATE  SITE  SALES  TOTAL_CUST  TOTAL_ACTIVE  WEEK_TREND
# 10910 2019-12-29     1    0.0           0           0.0         NaN
# 10911 2019-12-29     2    0.0           0           0.0         NaN
# 10912 2019-12-29     3    0.0           0           0.0         NaN
# 10913 2019-12-29     4    0.0           0           0.0         NaN
# 10914 2019-12-29     5    0.0           0           0.0         NaN
# 10915 2019-12-29     6    0.0           0           0.0 -100.000000
# 10916 2019-12-29     7    0.0           0           0.0  -77.663230
# 10917 2019-12-29     8    0.0           0           0.0  -61.862528
# 10918 2019-12-29     9    0.0           0           0.0         NaN
# 10919 2019-12-29    10    0.0           0           0.0 -100.000000
# 10920 2019-12-30     1    0.0           0           0.0         NaN
# 10921 2019-12-30     2    0.0           0           0.0         NaN
# 10922 2019-12-30     3  496.0           1           1.0         NaN
# 10923 2019-12-30     4  162.0           1           1.0         NaN
# 10924 2019-12-30     5    0.0           0           0.0         NaN
# 10925 2019-12-30     6    0.0           0           0.0 -100.000000
# 10926 2019-12-30     7    0.0           0           0.0  -77.663230
# 10927 2019-12-30     8    0.0           0           0.0  -61.862528
# 10928 2019-12-30     9    0.0           0           0.0         NaN
# 10929 2019-12-30    10    0.0           0           0.0 -100.000000
# 10930 2019-12-31     1    0.0           0           0.0         NaN
# 10931 2019-12-31     2    0.0           0           0.0         NaN
# 10932 2019-12-31     3    0.0           0           0.0         NaN
# 10933 2019-12-31     4    0.0           0           0.0         NaN
# 10934 2019-12-31     5    0.0           0           0.0         NaN
# 10935 2019-12-31     6    0.0           0           0.0 -100.000000
# 10936 2019-12-31     7    0.0           0           0.0 -100.000000
# 10937 2019-12-31     8  519.0           1           0.0  -16.693419
# 10938 2019-12-31     9    0.0           0           0.0         NaN
# 10939 2019-12-31    10    0.0           0           0.0 -100.000000

# %%
def rolling_year_trend(df, num_weeks, granularity):
    
    gap = num_weeks * 7
    
    current = df.rolling(gap)['SALES'].sum()    
    previous = df.shift(-365).rolling(gap)['SALES'].sum()
    
    df['DATA'] = (current/previous - 1) * 100
    df['DATA'] = df['DATA'].replace({np.inf:np.NaN})
    df['YEAR_TREND'] = df.groupby(granularity)['DATA'].shift(365)
    
    return df

# %%
def year_trend(sales, num_weeks, granularity):
    new_sales = group_on_variable(granularity, sales)
    granularity.remove('DATE')
    return new_sales.groupby(granularity, as_index=False).apply(rolling_year_trend, num_weeks, granularity).drop(columns='DATA')

# %%
year_trend(padded, 1, ['DATE', 'PROPOSITION']).tail()
# Out:
#            DATE PROPOSITION  SALES  TOTAL_CUST  TOTAL_ACTIVE  YEAR_TREND
# 3277 2019-12-30    In-store  162.0           1           1.0   -2.464066
# 3278 2019-12-30     Pick-up    0.0           0           0.0  145.348837
# 3279 2019-12-31    Delivery    0.0           0           0.0  -74.395161
# 3280 2019-12-31    In-store    0.0           0           0.0  114.120668
# 3281 2019-12-31     Pick-up  519.0           1           0.0   15.221580

# %%
def rolling_last_week(df, num_weeks, granularity):
    
    gap = num_weeks * 7
    
    df['LAST_N_WEEK_SALES'] = df.rolling(gap)['SALES'].sum()
    
    return df

# %%
def total_last_n_weeks(sales, num_weeks, granularity):
    new_sales = group_on_variable(granularity, sales)
    granularity.remove('DATE')
    return new_sales.groupby(granularity, as_index=False).apply(rolling_last_week, num_weeks, granularity)

# %%
total_last_n_weeks(padded, 2, ['DATE', 'PROPOSITION']).head(50)
# Out:
#          DATE PROPOSITION  SALES  TOTAL_CUST  TOTAL_ACTIVE  LAST_N_WEEK_SALES
# 0  2017-01-02    Delivery    0.0           0           0.0                NaN
# 1  2017-01-02    In-store   89.0           1           1.0                NaN
# 2  2017-01-02     Pick-up    0.0           0           0.0                NaN
# 3  2017-01-03    Delivery    0.0           0           0.0                NaN
# 4  2017-01-03    In-store    0.0           0           0.0                NaN
# 5  2017-01-03     Pick-up    0.0           0           0.0                NaN
# 6  2017-01-04    Delivery  282.0           1           0.0                NaN
# 7  2017-01-04    In-store    0.0           0           0.0                NaN
# 8  2017-01-04     Pick-up    0.0           0           0.0                NaN
# 9  2017-01-05    Delivery    0.0           0           0.0                NaN
# 10 2017-01-05    In-store    0.0           0           0.0                NaN
# 11 2017-01-05     Pick-up  182.0           1           1.0                NaN
# 12 2017-01-06    Delivery    0.0           0           0.0                NaN
# 13 2017-01-06    In-store    0.0           0           0.0                NaN
# 14 2017-01-06     Pick-up    0.0           0           0.0                NaN
# 15 2017-01-07    Delivery  297.0           1           0.0                NaN
# 16 2017-01-07    In-store  302.0           1           1.0                NaN
# 17 2017-01-07     Pick-up    0.0           0           0.0                NaN
# 18 2017-01-08    Delivery    0.0           0           0.0                NaN
# 19 2017-01-08    In-store    0.0           0           0.0                NaN
# 20 2017-01-08     Pick-up  209.0           1           0.0                NaN
# 21 2017-01-09    Delivery    0.0           0           0.0                NaN
# 22 2017-01-09    In-store    0.0           0           0.0                NaN
# 23 2017-01-09     Pick-up    0.0           0           0.0                NaN
# 24 2017-01-10    Delivery    0.0           0           0.0                NaN
# 25 2017-01-10    In-store    0.0           0           0.0                NaN
# 26 2017-01-10     Pick-up    0.0           0           0.0                NaN
# 27 2017-01-11    Delivery   87.0           1           0.0                NaN
# 28 2017-01-11    In-store  136.0           1           1.0                NaN
# 29 2017-01-11     Pick-up  471.0           1           1.0                NaN
# 30 2017-01-12    Delivery    0.0           0           0.0                NaN
# 31 2017-01-12    In-store  265.0           1           1.0                NaN
# 32 2017-01-12     Pick-up    0.0           0           0.0                NaN
# 33 2017-01-13    Delivery    0.0           0           0.0                NaN
# 34 2017-01-13    In-store  155.0           1           0.0                NaN
# 35 2017-01-13     Pick-up    0.0           0           0.0                NaN
# 36 2017-01-14    Delivery    0.0           0           0.0                NaN
# 37 2017-01-14    In-store  154.0           1           0.0                NaN
# 38 2017-01-14     Pick-up    0.0           0           0.0                NaN
# 39 2017-01-15    Delivery  589.0           1           0.0             1255.0
# 40 2017-01-15    In-store    0.0           0           0.0             1101.0
# 41 2017-01-15     Pick-up    0.0           0           0.0              862.0
# 42 2017-01-16    Delivery    0.0           0           0.0             1255.0
# 43 2017-01-16    In-store    0.0           0           0.0             1012.0
# 44 2017-01-16     Pick-up    0.0           0           0.0              862.0
# 45 2017-01-17    Delivery    0.0           0           0.0             1255.0
# 46 2017-01-17    In-store    0.0           0           0.0             1012.0
# 47 2017-01-17     Pick-up  288.0           1           0.0             1150.0
# 48 2017-01-18    Delivery    0.0           0           0.0              973.0
# 49 2017-01-18    In-store    0.0           0           0.0             1012.0
